# %%
import h5py
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
font1={'family':'Times New Roman',
       'weight': 'normal',
       'size':30,
}

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    dfraw = pd.read_hdf('F:/DB2/data/raw/DB2_s' + str(j) + 'raw.h5', 'df') 
    dfraw = np.array(dfraw)
   
    plt.plot(dfraw[:600000,:],label='raw' ),
    plt.xlabel('Samples',font1)
    plt.xlabel('sEMG signal',font1)
#     plt.legend(prop=font1,loc=1)

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    dfdown = pd.read_hdf('F:/DB2/data/down/DB2_s' + str(j) + 'down.h5', 'df') 
    dfdown = np.array(dfdown)
    plt.plot(dfdown[:30000,:],label='down'),
    plt.xlabel('Samples',font1)
    plt.xlabel('sEMG signal',font1)
#     plt.legend(prop=font1,loc=1)

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    df1 = pd.read_hdf('D:/Pengxiangdong/ZX/DB2/data/filter/DB2_s' + str(j) + 'filter.h5', 'df') 
    data = np.array(df1)
    plt.plot(data[11000:11500,5:12])

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    df = pd.read_hdf('D:/Pengxiangdong/ZX/DB2/data/raw/DB2_s' + str(j) + 'raw.h5', 'df') 
    data = np.array(df)
    plt.plot(data[11000:11500,5:12])
#         templabel = data[:, channel]
#         label =templabel.reshape((templabel.shape[0],1))
#         alldata = np.hstack((filteremg, label))

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    df = pd.read_hdf('D:/Pengxiangdong/ZX/DB2/data/raw/DB2_s' + str(j) + 'raw.h5', 'df') 
    data = np.array(df)
    plt.plot(data[11000:11500,5:12])

# %%
plt.figure(figsize=(20,8))
for j in range(1,2):
    df1 = pd.read_hdf('D:/Pengxiangdong/ZX/DB2/data/down/DB2_s' + str(j) + 'down.h5', 'df') 
    data = np.array(df1)
    plt.plot(data[:,:12])
